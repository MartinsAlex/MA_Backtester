# %% [markdown]
# # **Bonjour et bienvenue sur ma page dédiée à mon travail de bachelor !**
# ------
#
#
#
# ## Vous trouverez ici tout les fichiers et algorithmes que j'ai codés et utilisés pour mon travail.
#
# Les différents dossiers :
#
# - Fonctions : algorithmes servants aux tests
# - [Stratégies](https://github.com/MartinsAlex/Backtesting/tree/master/Strat%C3%A9gies) : exemples de stratégies analysées
# - [Listes de tickers](https://github.com/MartinsAlex/Backtesting/tree/master/Listes%20de%20tickers) : fichiers csv contenant quelques tickers (symbol) pouvant être utilisés
# - Documentation : fichier d'aide pour les fonction (..)

# %% [markdown]
# ## Example :
#
# Action Crédit Suisse, 2002 à 2010. Stratégie basée sur le croisement des moyennes mobiles 50 et 200 jours. Prise de position short et long, capital initial : 10'000 USD.

# %%
from MCF import MA_CROSS
import pandas as pd
# %matplotlib notebook

results, transactions, fig = MA_CROSS(["CS"], 50, 200, "2002-01-01", "2010-01-01", 
                                      ma="simple", showplot=True, shortLong="both", capital=10_000)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %% [markdown]
# ### La première table retournée contient les statistiques, résultats de la stratégie :

# %%
df1
# Out:
#          From          To Ticker Number of Trades Winning Trades  \
# 1  2000-08-21  2012-03-01     CS               13              6
#
#   Losing Trades Largest Winning Trade Largest Losing Trade % Profitable  \
# 1             7               14.4437               -4.899       0.4615
#
#   Expectancy Total Realized Return Buy & Hold Return Asset Return %  \
# 1    1.24352               3808.33          -3372.31      -0.337231
#
#   Strategy Return % Strategy Max Drawdown Asset Max Drawdown Open position  \
# 1          0.380833             -0.550653          -0.741855      -27.8666
#
#   Open Trade P/L Total Return Strategy Annualized Volatility  \
# 1        3974.04      3816.34                       0.475262
#
#   Asset Annualized Volatility Used Stop-Loss Used Stop-Gain  \
# 1                    0.466286              0              0
#
#   Asset Sharpe Ratio Market Exposure Strategy Sharpe Ratio  \
# 1         -0.0791476        0.880345            -0.0443419
#
# ...

# %% [markdown]
# ### La deuxième, les transactions effectuées :

# %%
df2
# Out:
#           Date        Type      Price Ticker        P/L Number of shares
# 0   2002-01-10    Buy Long  24.295078     CS        NaN              412
# 1   2002-03-01   Sell Long  19.396069     CS  -4.899010              412
# 2   2002-03-01   Buy Short  19.396069     CS        NaN              412
# 3   2003-05-16  Sell Short  15.650544     CS   3.745524              412
# 4   2003-05-16    Buy Long  15.650544     CS        NaN              609
# 5   2004-05-18   Sell Long  19.987370     CS   4.336825              609
# 6   2004-05-18   Buy Short  19.987370     CS        NaN              609
# 7   2004-11-19  Sell Short  23.428408     CS  -3.441038              609
# 8   2004-11-19    Buy Long  23.428408     CS        NaN              430
# 9   2006-08-14   Sell Long  33.985176     CS  10.556768              430
# 10  2006-08-14   Buy Short  33.985176     CS        NaN              430
# 11  2006-09-27  Sell Short  37.070122     CS  -3.084946              430
# ...
