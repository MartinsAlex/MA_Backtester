# %% [markdown]
# # Marché actions américain: SPDR S&P 500 ETF Trust (SPY)
#
# ## 1. " Golden and Death Cross " : 3 juillet 2000 au 3 juillet 2020

# %%
import analyzer as mb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook


strategy = mb.strategyDefiner(['spy'], 50, 200, "2000-07-02", "2020-07-02", shortLong="long",
                                 maType="simple", commission=.0005, capital=100_000, rf=.00133, plot=True)



strategy.analyse()


plt.show()
# Out:
# Working on ticker 1 / 1 (SPY)
# <img src="data:image/png;base64,..." width="1599.9999761581425">
# Done !

# %%
strategy.resultsTable
# Out:
#          From          To Ticker Number of Trades Winning Trades  \
# 1  2001-04-19  2020-07-02    SPY               10              7
#
#   Losing Trades Largest Winning Trade Largest Losing Trade Win Rate  \
# 1             3                113664             -24345.4      0.7
#
#   Expectancy Total Realized Return Total Return Buy & Hold Return  \
# 1    15.3096                247386       247386            260431
#
#   Asset Return % Strategy Realized Return % Out/Under-performance %  \
# 1        2.60431                    2.47386               -0.130453
#
#   Asset Annualized Return % Strategy Annualized Return %  \
# 1                 0.0691523                    0.0670987
#
#   Open position (price) Open Trade P/L Asset Annualized Volatility  \
# 1                   NaN            NaN                    0.196244
#
#   Strategy Annualized Volatility Asset Sharpe Ratio Strategy Sharpe Ratio  \
# 1                       0.132364           0.345602              0.514553
#
# ...

# %%
strategy.transactionTable
# Out:
#           Date       Type       Price Ticker        P/L Number of shares
# 0   2002-04-19   Buy Long   78.831650    SPY        NaN             1268
# 1   2002-05-17  Sell Long   77.448875    SPY  -1.382774             1268
# 2   2003-05-12   Buy Long   67.389915    SPY        NaN             1457
# 3   2004-08-25  Sell Long   80.447693    SPY  13.057777             1457
# 4   2004-10-27   Buy Long   82.076805    SPY        NaN             1427
# 5   2006-07-25  Sell Long   95.237175    SPY  13.160370             1427
# 6   2006-08-29   Buy Long   98.184708    SPY        NaN             1384
# 7   2007-12-28  Sell Long  113.927841    SPY  15.743134             1384
# 8   2009-06-18   Buy Long   73.566338    SPY        NaN             2142
# 9   2010-07-07  Sell Long   86.755753    SPY  13.189415             2142
# 10  2010-10-13   Buy Long   96.927765    SPY        NaN             1916
# 11  2011-08-17  Sell Long   99.805489    SPY   2.877724             1916
# ...

# %% [markdown]
# ## Saisonnalité des pertes et profits

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib notebook

fig, ax = plt.subplots(figsize = (16,8))

seasonTable = strategy.seasonalityTable()
seasonTable[seasonTable == 0] = np.nan
seasonTable = seasonTable.sort_values(by="Month")

seasonTable = seasonTable.reindex(['Jan', 'Feb', 'Mar', "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct",
    "Nov", "Dec"])

cmap = sns.diverging_palette(h_neg=10, h_pos=130, s=99, l=55, as_cmap=True, sep=2)

sns.heatmap(seasonTable, linewidths=.5, cmap=cmap, center=0, fmt=',.2f', annot=True)

plt.savefig("season.png", dpi=200)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1599.9999761581425">

# %% [markdown]
# # 2. Analyse "Walkforward"

# %% [markdown]
# ![PNG](walkforward.PNG)

# %% [markdown]
# # Résultat Échantillon (avec les paramètres originaux)

# %%
import analyzer as mb
import pandas as pd
# %matplotlib notebook


strategy = mb.strategyDefiner(['spy'], 50, 200, "2013-07-02", "2017-07-02", shortLong="long",
                                 maType="simple", commission=.0005, capital=100_000, rf=.00133)


strategy.analyse()

strategy.resultsTable
# Out:
# C:\Users\Alex\Anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# Working on ticker 1 / 1 (SPY)
# Done !
#          From          To Ticker Number of Trades Winning Trades  \
# 1  2014-04-17  2017-06-30    SPY                1              0
#
#   Losing Trades Largest Winning Trade Largest Losing Trade Win Rate  \
# 1             1              -7990.66             -7990.66        0
#
#   Expectancy Total Realized Return Total Return Buy & Hold Return  \
# 1   -14.9358              -8040.65      8477.91           38554.8
#
#   Asset Return % Strategy Realized Return % Out/Under-performance %  \
# 1       0.385548                 -0.0804065               -0.465954
#
#   Asset Annualized Return % Strategy Annualized Return %  \
# 1                  0.107055                   -0.0258042
#
# ...

# %% [markdown]
# ## Détermination de la combinaison optimale (échantillon)

# %%
import analyzer as mb
import pandas as pd
# %matplotlib notebook


strategy = mb.strategyDefiner(['spy'], 50, 200, "2013-07-02", "2017-07-02", shortLong="long",
                                 maType="simple", commission=.0005, capital=100_000, rf=.00133)


allCombin = strategy.optimize("Strategy Sharpe Ratio", fastMaRange= [40, 60],  slowMaRange = [190, 210], type="max")
# Out:
# C:\Users\Alex\Anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# 441 combinaisons possibles found, it may take some times. Continue ? y/n
# y
#
#  Trying combinaison 0/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 1/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 2/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 3/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 4/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 5/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 6/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 7/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 8/441
# Working on ticker 1 / 1 (SPY)
# Done !
#
#  Trying combinaison 9/441
# ...

# %% [markdown]
# ## Résultat hors-échantillon (avec les paramètres originaux)

# %%
import analyzer as mb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook


strategy = mb.strategyDefiner(['spy'], 50, 200, "2017-07-02", "2020-07-02", shortLong="long",
                                 maType="simple", commission=.0005, capital=100_000, rf=.00133, plot=True)



strategy.analyse()





plt.show()
# Out:
# Working on ticker 1 / 1 (SPY)
# <img src="data:image/png;base64,..." width="1599.9999761581425">
# Done !

# %%
strategy.resultsTable
# Out:
#          From          To Ticker Number of Trades Winning Trades  \
# 1  2018-04-19  2020-07-02    SPY                1              0
#
#   Losing Trades Largest Winning Trade Largest Losing Trade Win Rate  \
# 1             1              -6429.42             -6429.42        0
#
#   Expectancy Total Realized Return Total Return Buy & Hold Return  \
# 1   -17.6632              -6479.34     -6479.34             21321
#
#   Asset Return % Strategy Realized Return % Out/Under-performance %  \
# 1        0.21321                 -0.0647934               -0.278004
#
#   Asset Annualized Return % Strategy Annualized Return %  \
# 1                 0.0915483                   -0.0299051
#
#   Open position (price) Open Trade P/L Asset Annualized Volatility  \
# 1                   NaN            NaN                    0.245328
#
#   Strategy Annualized Volatility Asset Sharpe Ratio Strategy Sharpe Ratio  \
# 1                       0.260605           0.367746             -0.190194
#
# ...

# %%
strategy.transactionTable
# Out:
#          Date       Type       Price Ticker        P/L Number of shares
# 0  2019-03-26   Buy Long  274.283966    SPY        NaN              364
# 1  2020-03-31  Sell Long  256.620728    SPY -17.663239              364

# %% [markdown]
# ## Résultat hors-échantillon (avec les paramètres optimaux : 44 - 190)

# %%
import analyzer as mb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook


strategy = mb.strategyDefiner(['spy'], 44, 190, "2017-07-02", "2020-07-02", shortLong="long",
                                 maType="simple", commission=.0005, capital=100_000, rf=.00133, plot=True)



strategy.analyse()



plt.show()
# Out:
# Working on ticker 1 / 1 (SPY)
# <img src="data:image/png;base64,..." width="1599.9999761581425">
# Done !

# %%
strategy.resultsTable
# Out:
#          From          To Ticker Number of Trades Winning Trades  \
# 1  2018-04-05  2020-07-02    SPY                1              0
#
#   Losing Trades Largest Winning Trade Largest Losing Trade Win Rate  \
# 1             1              -5602.76             -5602.76        0
#
#   Expectancy Total Realized Return Total Return Buy & Hold Return  \
# 1   -15.4772              -5652.63     -1875.21           22805.3
#
#   Asset Return % Strategy Realized Return % Out/Under-performance %  \
# 1       0.228053                 -0.0565263                -0.28458
#
#   Asset Annualized Return % Strategy Annualized Return %  \
# 1                  0.095777                   -0.0255738
#
#   Open position (price) Open Trade P/L Asset Annualized Volatility  \
# 1                300.05        3824.53                    0.244165
#
#   Strategy Annualized Volatility Asset Sharpe Ratio Strategy Sharpe Ratio  \
# 1                       0.256648           0.386816            -0.0517784
#
# ...

# %%
strategy.transactionTable
# Out:
#          Date       Type       Price Ticker        P/L Number of shares
# 0  2019-03-19   Buy Long  275.532837    SPY        NaN              362
# 1  2020-03-26  Sell Long  260.055603    SPY -15.477234              362
# 2  2020-06-26   Buy Long  300.049988    SPY        NaN              314
