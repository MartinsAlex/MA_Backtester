# %% [markdown]
# # 3.2	Forex : 22 devises cotées en USD
# ## 1. " Golden and Death Cross " : 3 juillet 2000 au 3 juillet 2020

# %%
import analyzer as mb
import pandas as pd


forexFREDlist =  ['DEXUSAL', 'DEXBZUS', 'DEXUSUK', 'DEXCAUS', 'DEXCHUS', 'DEXDNUS', 'DEXUSEU',
                  'DEXHKUS', 'DEXINUS','DEXJPUS','DEXMAUS','DEXMXUS','DEXTAUS','DEXUSNZ',
                  'DEXNOUS','DEXSIUS', 'DEXSFUS', 'DEXKOUS','DEXSLUS','DEXSDUS','DEXSZUS','DEXTHUS']



strategy = mb.strategyDefiner(forexFREDlist, 50, 200, "2000-07-3", "2020-07-3", shortLong="long",
                                 maType="simple", commission=.0005, capital=100_000, rf=.00133)




strategy.analyse()
# Out:
# Working on ticker 1 / 22 (DEXUSAL)
# Working on ticker 2 / 22 (DEXBZUS)
# Working on ticker 3 / 22 (DEXUSUK)
# Working on ticker 4 / 22 (DEXCAUS)
# Working on ticker 5 / 22 (DEXCHUS)
# Working on ticker 6 / 22 (DEXDNUS)
# Working on ticker 7 / 22 (DEXUSEU)
# Working on ticker 8 / 22 (DEXHKUS)
# Working on ticker 9 / 22 (DEXINUS)
# Working on ticker 10 / 22 (DEXJPUS)
# Working on ticker 11 / 22 (DEXMAUS)
# Working on ticker 12 / 22 (DEXMXUS)
# Working on ticker 13 / 22 (DEXTAUS)
# Working on ticker 14 / 22 (DEXUSNZ)
# Working on ticker 15 / 22 (DEXNOUS)
# Working on ticker 16 / 22 (DEXSIUS)
# Working on ticker 17 / 22 (DEXSFUS)
# Working on ticker 18 / 22 (DEXKOUS)
# Working on ticker 19 / 22 (DEXSLUS)
# Working on ticker 20 / 22 (DEXSDUS)
# Working on ticker 21 / 22 (DEXSZUS)
# Working on ticker 22 / 22 (DEXTHUS)
# Done !

# %%
strategy.resultsTable
# Out:
#           From          To   Ticker Number of Trades Winning Trades  \
# 1   2001-04-19  2020-07-02  DEXUSAL               12              4
# 2   2001-04-19  2020-07-02  DEXBZUS               14              6
# 3   2001-04-19  2020-07-02  DEXUSUK               15              6
# 4   2001-04-19  2020-07-02  DEXCAUS               15              5
# 5   2001-04-19  2020-07-02  DEXCHUS               12              4
# 6   2001-04-19  2020-07-02  DEXDNUS               13              6
# 7   2001-04-19  2020-07-02  DEXUSEU               13              5
# 8   2001-04-19  2020-07-02  DEXHKUS               19              4
# 9   2001-04-19  2020-07-02  DEXINUS               12              4
# 10  2001-04-19  2020-07-02  DEXJPUS               15              6
# 11  2001-04-19  2020-07-02  DEXMAUS               14              4
# 12  2001-04-19  2020-07-02  DEXMXUS               18              4
# 13  2001-04-19  2020-07-02  DEXTAUS               13              6
# ...

# %%
strategy.resultsTable.mean()
# Out:
# Number of Trades                      13.590909
# Winning Trades                         5.545455
# Losing Trades                          7.909091
# Largest Winning Trade              20647.807418
# Largest Losing Trade               -8352.858614
# Win Rate                               0.411500
# Expectancy                             0.002793
# Total Realized Return              12091.714078
# Total Return                       12646.586250
# Buy & Hold Return                   4107.095745
# Asset Return %                         0.041071
# Strategy Realized Return %             0.120917
# Out/Under-performance %                0.079846
# Asset Annualized Return %             -0.001814
# Strategy Annualized Return %           0.004775
# Open position (price)                  0.406729
# Open Trade P/L                      1586.094295
# Asset Annualized Volatility            0.092914
# Strategy Annualized Volatility         0.060884
# Asset Sharpe Ratio                    -0.035496
# ...

# %% [markdown]
# ## Rendements annualisés

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# %matplotlib notebook

fig, ax = plt.subplots(figsize = (12,6))

barWidth = 0.3


df = strategy.resultsTable[["Ticker", 'Strategy Annualized Return %', 'Asset Annualized Return %']]


df = df.sort_values(by=['Asset Annualized Return %'])


labels = df["Ticker"]
a = df['Strategy Annualized Return %']*100
b = df['Asset Annualized Return %']*100


r1 = np.arange(len(labels))
r2 = [x + barWidth for x in r1]


ax.bar(r1, a, color='red', width=barWidth, edgecolor='black', label='Rdt annualisé stratégie', align='edge', zorder=3, 
      linewidth=1)
ax.bar(r2, b, color='blue', width=barWidth, edgecolor='black', label='Rdt annualisé monnaie', align='edge', zorder=3, 
      linewidth=1)

plt.xticks([r + barWidth for r in range(len(labels))], labels, rotation=80)


ax.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.tight_layout()

ax.grid(zorder=0)


ax.legend()


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1199.9999821186068">

# %% [markdown]
# ## Sharpe ratios

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# %matplotlib notebook

fig, ax = plt.subplots(figsize = (12,6))

barWidth = 0.3

    

df = strategy.resultsTable[["Ticker", 'Strategy Sharpe Ratio', 'Asset Sharpe Ratio']]


df = df.sort_values(by=['Asset Sharpe Ratio'])



    
labels = df["Ticker"]
a = df['Strategy Sharpe Ratio']
b = df['Asset Sharpe Ratio']


r1 = np.arange(len(labels))
r2 = [x + barWidth for x in r1]


ax.bar(r1, a, color='red', width=barWidth, edgecolor='black', label='Sharpe Ratio Stratégie', align='edge', zorder=3, 
      linewidth=1)
ax.bar(r2, b, color='blue', width=barWidth, edgecolor='black', label='Sharpe Ratio Monnaie', align='edge', zorder=3, 
      linewidth=1)


plt.xticks([r + barWidth for r in range(len(labels))], labels, rotation=80)


plt.tight_layout()

ax.grid(zorder=0)


ax.legend()


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1199.9999821186068">

# %% [markdown]
# ## Saisonnalité des pertes et profits

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib notebook

fig, ax = plt.subplots(figsize = (12,6))

seasonTable = strategy.seasonalityTable()
seasonTable = seasonTable.sort_values(by="Month")

seasonTable = seasonTable.reindex(['Jan', 'Feb', 'Mar', "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct",
    "Nov", "Dec"])

cmap = sns.diverging_palette(h_neg=10, h_pos=130, s=99, l=55, as_cmap=True, sep=2)

sns.heatmap(seasonTable, linewidths=.5, cmap=cmap, center=0)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1199.9999821186068">

# %% [markdown]
# # Les performances exceptionnelles :
#
# ## 1. Le Rand Sud-Africain

# %%
import analyzer as mb
import pandas as pd
# %matplotlib notebook

strategy = mb.strategyDefiner(["DEXSFUS"], 50, 200, "2000-07-3", "2020-07-3", shortLong="long",
                                 maType="simple", commission=.0005, capital=100_000, rf=.00133, plot=True)




strategy.analyse()


plt.show()
# Out:
# Working on ticker 1 / 1 (DEXSFUS)
# <img src="data:image/png;base64,..." width="1599.9999761581425">
# Done !

# %%
strategy.resultsTable
# Out:
#          From          To   Ticker Number of Trades Winning Trades  \
# 1  2001-04-09  2020-07-03  DEXSFUS               12              5
#
#   Losing Trades Largest Winning Trade Largest Losing Trade Win Rate  \
# 1             7               56622.3             -18744.6   0.4167
#
#     Expectancy Total Realized Return Total Return Buy & Hold Return  \
# 1  0.000806885               6237.84      6237.84            -52468
#
#   Asset Return % Strategy Realized Return % Out/Under-performance %  \
# 1       -0.52468                  0.0623784                0.587058
#
#   Asset Annualized Return % Strategy Annualized Return %  \
# 1                -0.0380743                   0.00316309
#
#   Open position (price) Open Trade P/L Asset Annualized Volatility  \
# 1                   NaN            NaN                    0.174863
#
#   Strategy Annualized Volatility Asset Sharpe Ratio Strategy Sharpe Ratio  \
# 1                       0.114485          -0.225343             0.0198902
# ...

# %% [markdown]
# ## 2. La couronne suédoise

# %%
import analyzer as mb
import pandas as pd
# %matplotlib notebook

strategy = mb.strategyDefiner(["DEXSDUS"], 50, 200, "2000-07-3", "2020-07-3", shortLong="long",
                                 maType="simple", commission=.0005, capital=100_000, rf=.00133, plot=True)




strategy.analyse()


plt.show()
# Out:
# Working on ticker 1 / 1 (DEXSDUS)
# <img src="data:image/png;base64,..." width="1599.9999761581425">
# Done !

# %%
strategy.resultsTable
# Out:
#          From          To   Ticker Number of Trades Winning Trades  \
# 1  2001-04-19  2020-07-02  DEXSDUS               13              8
#
#   Losing Trades Largest Winning Trade Largest Losing Trade Win Rate  \
# 1             5                 39858               -10594   0.6154
#
#    Expectancy Total Realized Return Total Return Buy & Hold Return  \
# 1  0.00502576               66914.4      69187.2           8735.76
#
#   Asset Return % Strategy Realized Return % Out/Under-performance %  \
# 1      0.0873576                   0.669144                0.581787
#
#   Asset Annualized Return % Strategy Annualized Return %  \
# 1                0.00456279                     0.028239
#
#   Open position (price) Open Trade P/L Asset Annualized Volatility  \
# 1              0.105773         2356.2                    0.121174
#
#   Strategy Annualized Volatility Asset Sharpe Ratio Strategy Sharpe Ratio  \
# 1                      0.0821027          0.0266789              0.348473
#
# ...
