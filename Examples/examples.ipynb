# %% [markdown]
# ## Example 1 :
#
# #### Action Crédit Suisse, de 2002 à 2010. Stratégie basée sur le croisement des moyennes mobiles 50 et 200 jours.
# - Type de moyenne : simple
# - Capital initial : 10'000 USD
# - Prise de position short et long.

# %%
from MCF import MA_CROSS

# %matplotlib inline

results, transactions, fig = MA_CROSS(["CS"], 50, 200, "2002-01-01", "2010-01-01", 
                                      ma="simple", showplot=True, shortLong="both", capital=10_000)

# %% [markdown]
# ### La première table contient les statistiques, résultats de la stratégie :

# %%
results
# Out:
#          From          To Ticker Number of Trades Winning Trades  \
# 1  2002-01-02  2009-12-31     CS                6              4
#
#   Losing Trades Largest Winning Trade Largest Losing Trade % Profitable  \
# 1             2               14.4437               -3.441       0.6667
#
#   Expectancy Total Realized Return Buy & Hold Return Asset Return %  \
# 1    4.83404               11701.6           4056.48       0.405648
#
#   Strategy Return % Strategy Max Drawdown Asset Max Drawdown Open position  \
# 1           1.17016             -0.550653          -0.741855       28.8194
#
#   Open Trade P/L Total Return Strategy Annualized Volatility  \
# 1        3579.12      11706.3                       0.466848
#
#   Asset Annualized Volatility Used Stop-Loss Used Stop-Gain  \
# 1                     0.48502              0              0
#
#   Asset Sharpe Ratio Market Exposure Strategy Sharpe Ratio  \
# 1          0.0854698        0.828288              0.244373
#
# ...

# %% [markdown]
# ### La deuxième, la liste des transactions réalisées :

# %%
transactions
# Out:
#           Date        Type      Price Ticker        P/L Number of shares
# 0   2003-05-16    Buy Long  15.650544     CS        NaN              639
# 1   2004-05-18   Sell Long  19.987370     CS   4.336825              639
# 2   2004-05-18   Buy Short  19.987370     CS        NaN              639
# 3   2004-11-19  Sell Short  23.428408     CS  -3.441038              639
# 4   2004-11-19    Buy Long  23.428408     CS        NaN              451
# 5   2006-08-14   Sell Long  33.985176     CS  10.556768              451
# 6   2006-08-14   Buy Short  33.985176     CS        NaN              451
# 7   2006-09-27  Sell Short  37.070122     CS  -3.084946              451
# 8   2006-09-27    Buy Long  37.070122     CS        NaN              376
# 9   2007-08-23   Sell Long  43.263081     CS   6.192959              376
# 10  2007-08-23   Buy Short  43.263081     CS        NaN              376
# 11  2009-05-19  Sell Short  28.819414     CS  14.443666              376
# ...
